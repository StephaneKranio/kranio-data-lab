# %%
import pandas as pd

# Lire le fichier Parquet
df = pd.read_parquet('test.parquet')
df
# Renommer les colonnes
#df.columns = ["ID_Client", "Nom_Client", "Date_Inscription", "Email"]

# Enregistrer avec le bon format
#df.to_parquet('path/to/fixed_file.parquet', index=False)
# Out:
#           DATE ID_PRODUIT ID_CLIENT QUANTITE_VENDUE PRIX_UNITAIRE  \
# 0   12-10-2023         39         9               9         65.45
# 1   12-10-2023         29        88              17         28.79
# 2   12-10-2023         15         1              17         61.04
# 3   12-10-2023         43         8              12         97.99
# 4   12-10-2023          8        88               7         51.24
# ..         ...        ...       ...             ...           ...
# 95  12-10-2023         15        44              17         47.02
# 96  12-10-2023         45        24               1         27.78
# 97  12-10-2023          1        79              16         13.92
# 98  12-10-2023         25        59              12         22.37
# 99  12-10-2023          7        32              19         93.79
#
#    INGESTION_DATE       EXECUTION_DATE
# 0      2025-01-23  2025-01-23 13:22:50
# 1      2025-01-23  2025-01-23 13:22:50
# 2      2025-01-23  2025-01-23 13:22:50
# ...
